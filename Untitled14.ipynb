# %%
import pandas as pd
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
df = pd.read_csv("/content/project.csv", encoding='latin1')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37057 entries, 0 to 37056
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   HeartDisease      37057 non-null  object
#  1   BMI               37057 non-null  float64
#  2   Smoking           37057 non-null  object
#  3   AlcoholDrinking   37057 non-null  object
#  4   Stroke            37057 non-null  object
#  5   PhysicalHealth    37057 non-null  int64
#  6   MentalHealth      37031 non-null  float64
#  7   DiffWalking       37057 non-null  object
#  8   Sex               37057 non-null  object
#  9   Diabetic          37057 non-null  object
#  10  PhysicalActivity  37057 non-null  object
#  11  GenHealth         37048 non-null  object
#  12  SleepTime         37056 non-null  float64
#  13  Asthma            37056 non-null  object
#  14  KidneyDisease     37056 non-null  object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 4.2+ MB

# %%
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No               3
# 1           No  20.34      No              No    Yes               0
# 2           No  26.58     Yes              No     No              20
# 3           No  24.21      No              No     No               0
# 4           No  23.71      No              No     No              28
#
#    MentalHealth DiffWalking     Sex Diabetic PhysicalActivity  GenHealth  \
# 0          30.0          No  Female      Yes              Yes  Very good
# 1           0.0          No  Female       No              Yes  Very good
# 2          30.0          No    Male      Yes              Yes       Fair
# 3           0.0          No  Female       No               No       Good
# 4           0.0         Yes  Female       No              Yes  Very good
#
#    SleepTime Asthma KidneyDisease
# 0        5.0    Yes            No
# 1        7.0     No            No
# ...

# %%
df.isnull().sum()
# Out:
# HeartDisease         0
# BMI                  0
# Smoking              0
# AlcoholDrinking      0
# Stroke               0
# PhysicalHealth       0
# MentalHealth        26
# DiffWalking          0
# Sex                  0
# Diabetic             0
# PhysicalActivity     0
# GenHealth            9
# SleepTime            1
# Asthma               1
# KidneyDisease        1
# dtype: int64

# %%
df['Asthma'].dtype
# Out:
# dtype('O')

# %%
from sklearn import preprocessing
import numpy as np
label_encoder = preprocessing.LabelEncoder()
for i in df:
  if df[i].dtype=='O':
    df[i]= label_encoder.fit_transform(df[i])
  
    df[i].unique()

# %%
df.isnull().sum()
# Out:
# HeartDisease         0
# BMI                  0
# Smoking              0
# AlcoholDrinking      0
# Stroke               0
# PhysicalHealth       0
# MentalHealth        26
# DiffWalking          0
# Sex                  0
# Diabetic             0
# PhysicalActivity     0
# GenHealth            0
# SleepTime            1
# Asthma               0
# KidneyDisease        0
# dtype: int64

# %%
df['MentalHealth'].fillna(df['MentalHealth'].mean(), inplace = True)
df['SleepTime'].fillna(df['SleepTime'].mean(), inplace = True)

# %%
df.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37057 entries, 0 to 37056
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   HeartDisease      37057 non-null  int64
#  1   BMI               37057 non-null  float64
#  2   Smoking           37057 non-null  int64
#  3   AlcoholDrinking   37057 non-null  int64
#  4   Stroke            37057 non-null  int64
#  5   PhysicalHealth    37057 non-null  int64
#  6   MentalHealth      37057 non-null  float64
#  7   DiffWalking       37057 non-null  int64
#  8   Sex               37057 non-null  int64
#  9   Diabetic          37057 non-null  int64
#  10  PhysicalActivity  37057 non-null  int64
#  11  GenHealth         37057 non-null  int64
#  12  SleepTime         37057 non-null  float64
#  13  Asthma            37057 non-null  int64
#  14  KidneyDisease     37057 non-null  int64
# dtypes: float64(3), int64(12)
# memory usage: 4.2 MB

# %%
import seaborn as sn
sn.scatterplot( data=df)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/events.py:88: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
for i in df:
  Q1 = np.percentile(df[i], 25,
                    interpolation = 'midpoint')
  
  Q3 = np.percentile(df[i], 75,
                    interpolation = 'midpoint')
  IQR = Q3 - Q1 

  upper = np.where(df[i]>= (Q3+1.5*IQR))

  lower = np.where(df[i]<= (Q1-1.5*IQR))
  
 
  df[i].drop(upper[0], inplace = True)
  df[i].drop(lower[0], inplace = True)

# %%
import matplotlib.pyplot as plt
import numpy as np
 
 

 

for i in df:
  plt.boxplot(df[i])

  plt.show()

# %%
sn.heatmap(df.corr())

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


scaling=StandardScaler()
 

scaling.fit(df)
Scaled_data=scaling.transform(df)
 

principal=PCA(n_components=3)
principal.fit(Scaled_data)
x=principal.transform(Scaled_data)

print(x.shape)
# Out:
# (37057, 3)

# %%
x
# Out:
# array([[ 1.22199411, -2.71533744,  0.70678408],
#        [-0.15004898,  0.85439484,  0.16021575],
#        [ 2.35967309, -1.48239847,  0.75898606],
#        ...,
#        [ 2.02606939, -0.58749938,  0.77477485],
#        [-0.28468818, -2.19084016, -0.17426253],
#        [ 2.10305105,  0.26233467, -1.48248839]])

# %%
df1=pd.DataFrame(x)
corr = df1.corr()
sn.heatmap(corr, annot = True)

# %%
X = df1
y = df['HeartDisease']
print(X)
print(y)
# Out:
#               0         1         2
# 0      1.221994 -2.715337  0.706784
# 1     -0.150049  0.854395  0.160216
# 2      2.359673 -1.482398  0.758986
# 3     -0.389535 -0.494592 -0.835363
# 4      1.595789 -0.802062 -0.792924
# ...         ...       ...       ...
# 37052  0.144322 -2.396530  0.314317
# 37053 -0.523581  0.297030 -0.111243
# 37054  2.026069 -0.587499  0.774775
# 37055 -0.284688 -2.190840 -0.174263
# 37056  2.103051  0.262335 -1.482488
#
# [37057 rows x 3 columns]
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 37052    0
# 37053    0
# 37054    0
# 37055    0
# 37056    0
# Name: HeartDisease, Length: 37057, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
xtrain = sc_x.fit_transform(X_train) 
xtest = sc_x.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(xtrain, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(xtest)

print(y_pred)
# Out:
# [0 0 0 ... 0 0 0]

# %%
from sklearn.metrics import accuracy_score
print ("Accuracy : ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy :  0.9595250944414463

# %%
from sklearn.metrics import multilabel_confusion_matrix
y_train=y_train[0:9265]

# %%
# Out:
# (9265,)

# %%
multilabel_confusion_matrix(y_train, y_test)
# Out:
# array([[[  54,  749],
#         [ 693, 7769]],
#
#        [[7769,  693],
#         [ 749,   54]]])

# %%
from sklearn.metrics import precision_score, recall_score
precision_score(y_train, y_pred)
# Out:
# 0.07475083056478406

# %%
recall_score(y_train, y_pred)
# Out:
# 0.05603985056039851
